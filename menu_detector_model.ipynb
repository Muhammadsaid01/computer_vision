# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammadsaid01/computer_vision/blob/main/menu_detector_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Menu Detector")
# Out:
# Menu Detector
